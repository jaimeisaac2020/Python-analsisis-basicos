# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimeisaac2020/Python-analsisis-basicos/blob/mi-github/Newton_Python_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UNIVERSIDAD DE EL SALVADOR
#
# # FACULTAD MULTIDISCIPLINARIA DE OCCIDENTE
#
# # DEPARTAMENTO DE MATEMATICA.
#
# ![minerva3.png](data:image/png;base64,...)
#
# # ALGEBRA 2 PROFESORADO EN MATEMATICA
#
# # METODO DE NEWTON RHAPSON EN PYTHON Y GOOGLE COLAB.
#
# # ALUMNO JAIME ISAAC PEÑA MEJIA.

# %% [markdown]
# ## **Calcular una raiz real de la funcion:** $x^3+4x^2-10=0$

# %%
# Método de Newton-Raphson
# Ejemplo 1 (Burden ejemplo 1 p.51/pdf.61)

import numpy as np

# INGRESO
fx  = lambda x: x**3 + 4*(x**2) - 10
dfx = lambda x: 3*(x**2) + 8*x

x0 = 2
tolera = 0.001

# PROCEDIMIENTO
tabla = []
tramo = abs(2*tolera)
xi = x0
while (tramo>=tolera):
    xnuevo = xi - fx(xi)/dfx(xi)
    tramo  = abs(xnuevo-xi)
    tabla.append([xi,xnuevo,tramo])
    xi = xnuevo

# convierte la lista a un arreglo.
tabla = np.array(tabla)
n = len(tabla)

# SALIDA
print(['xi', 'xnuevo', 'tramo'])
np.set_printoptions(precision = 4)
print(tabla)
print('raiz en: ', xi)
print('con error de: ',tramo)
# Out:
# ['xi', 'xnuevo', 'tramo']
# [[2.0000e+00 1.5000e+00 5.0000e-01]
#  [1.5000e+00 1.3733e+00 1.2667e-01]
#  [1.3733e+00 1.3653e+00 8.0713e-03]
#  [1.3653e+00 1.3652e+00 3.2001e-05]]
# raiz en:  1.3652300139161466
# con error de:  3.200095847999407e-05

# %%
from scipy.optimize import newton

# %%
fx=lambda x: x**3+4*x**2-10
x0=2
tolera=0.000001

# %%
dfx=lambda x: 3*x**2+8*x

# %%
import scipy.optimize as opt
opt.newton(fx,x0, fprime=dfx, tol = tolera)
# Out:
# 1.3652300134140969
