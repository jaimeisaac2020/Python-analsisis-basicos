# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimeisaac2020/Python-analsisis-basicos/blob/mi-github/Yahoo_Finance_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Yahoo Finance
# Si quieres tener los datos de precios de índices actualizados a día de hoy, lo puedes hacer de la siguiente manera. Estos datos han sido obtenidos mediante [Yahoo Finance](https://es.finance.yahoo.com/), una plataforma donde puedes ver, obtener, estudiar, analizar y comparar los precios de cierre de diferentes de acciones de los mercados financieros. La forma de obtener los datos de Yahoo Finance en Python es mediante el paquete `yfinance` que tendremos que instalar e importar.

# %%
# !pip install yfinance
import yfinance

# %% [markdown]
# Para obtener los precios de cierre de los índices SP500, FTSE, DAX y NIKKEI, especificar los nombres, la fecha de inicio y fin, y el intervalo (diario=1d):

# %%
raw_data = yfinance.download (tickers = "^GSPC ^FTSE ^N225 ^GDAXI", start = "1994-01-07",
                              end = "2020-05-17", interval = "1d", group_by = 'ticker', auto_adjust = True)
# Out:
# [*********************100%%**********************]  4 of 4 completed

# %%
raw_data.head()
# Out:
#                    ^N225                                                   \
#                     Open          High           Low         Close Volume
# Date
# 1994-01-07  17842.980469  18131.410156  17787.480469  18124.009766    0.0
# 1994-01-10  18186.519531  18567.060547  18186.519531  18443.439453    0.0
# 1994-01-11  18481.849609  18671.669922  18373.039062  18485.250000    0.0
# 1994-01-12  18447.339844  18807.080078  18301.929688  18793.880859    0.0
# 1994-01-13  18770.380859  18823.380859  18548.750000  18577.259766    0.0
#
#                  ^GDAXI                                                \
#                    Open         High          Low        Close Volume
# Date
# 1994-01-07  2218.959961  2227.639893  2201.820068  2224.949951    0.0
# 1994-01-10  2231.840088  2238.010010  2222.000000  2225.000000    0.0
# 1994-01-11  2225.429932  2235.610107  2225.179932  2228.100098    0.0
# 1994-01-12  2227.120117  2227.790039  2182.060059  2182.060059    0.0
# ...

# %%
#w_data1 = yfinance.download (tickers = "^GSPC ^FTSE ^N225 ^GDAXI", start = "1995-01-07",
                              #end = "2021-05-17", interval = "1m", group_by = 'ticker', auto_adjust = True)
# Out:
# [*********************100%%**********************]  4 of 4 completed
# ERROR:yfinance:
# 4 Failed downloads:
# ERROR:yfinance:['^GDAXI']: Exception('%ticker%: 1m data not available for startTime=789433200 and endTime=1621202400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.')
# ERROR:yfinance:['^N225']: Exception('%ticker%: 1m data not available for startTime=789404400 and endTime=1621177200. Only 7 days worth of 1m granularity data are allowed to be fetched per request.')
# ERROR:yfinance:['^GSPC']: Exception('%ticker%: 1m data not available for startTime=789454800 and endTime=1621224000. Only 7 days worth of 1m granularity data are allowed to be fetched per request.')
# ERROR:yfinance:['^FTSE']: Exception('%ticker%: 1m data not available for startTime=789436800 and endTime=1621206000. Only 7 days worth of 1m granularity data are allowed to be fetched per request.')

# %%
#w_data2 = yfinance.download (tickers = "^GSPC", start = "1994-01-07",
                              #end = "2020-05-17", interval = "1y", group_by = 'ticker', auto_adjust = True)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['^GSPC']: Exception('%ticker%: Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]')

# %%
df_comp=raw_data.copy()

# %% [markdown]
# Para cada día y cada precio obtenemos 4 datos, los precios de: apertura, máximo, bajo, cierre y volumen. Queremos los precios de cierre así que seleccionamos sólo la variable cierre para cada precio, los guardamos en 4 nuevas variables en el dataset y les ponemos los nombres del indice al que corresponden.

# %%
df_comp['spx'] = df_comp['^GSPC'].Close[:]
df_comp['dax'] = df_comp['^GDAXI'].Close[:]
df_comp['ftse'] = df_comp['^FTSE'].Close[:]
df_comp['nikkei'] = df_comp['^N225'].Close[:]

# %%
df_comp.head()
# Out:
#                  ^GDAXI                                                \
#                    Open         High          Low        Close Volume
# Date
# 1994-01-07  2218.959961  2227.639893  2201.820068  2224.949951    0.0
# 1994-01-10  2231.840088  2238.010010  2222.000000  2225.000000    0.0
# 1994-01-11  2225.429932  2235.610107  2225.179932  2228.100098    0.0
# 1994-01-12  2227.120117  2227.790039  2182.060059  2182.060059    0.0
# 1994-01-13  2171.500000  2183.709961  2134.100098  2142.370117    0.0
#
#                    ^N225                                                   \
#                     Open          High           Low         Close Volume
# Date
# 1994-01-07  17842.980469  18131.410156  17787.480469  18124.009766    0.0
# 1994-01-10  18186.519531  18567.060547  18186.519531  18443.439453    0.0
# 1994-01-11  18481.849609  18671.669922  18373.039062  18485.250000    0.0
# 1994-01-12  18447.339844  18807.080078  18301.929688  18793.880859    0.0
# ...

# %% [markdown]
# Pre-procesado: eliminar las variables que sobran, arreglar la frecuencia a business days y rellenar datos faltantes.

# %%
df_comp
# Out:
#                   ^GDAXI                                            \
#                     Open          High           Low         Close
# Date
# 1994-01-07   2218.959961   2227.639893   2201.820068   2224.949951
# 1994-01-10   2231.840088   2238.010010   2222.000000   2225.000000
# 1994-01-11   2225.429932   2235.610107   2225.179932   2228.100098
# 1994-01-12   2227.120117   2227.790039   2182.060059   2182.060059
# 1994-01-13   2171.500000   2183.709961   2134.100098   2142.370117
# ...                  ...           ...           ...           ...
# 2020-05-11  10948.240234  10986.219727  10740.820312  10824.990234
# 2020-05-12  10777.740234  10886.009766  10772.580078  10819.500000
# 2020-05-13  10669.990234  10698.129883  10530.320312  10542.660156
# 2020-05-14  10418.040039  10474.080078  10160.889648  10337.019531
# 2020-05-15  10470.849609  10547.190430  10382.540039  10465.169922
#
#                                 ^N225                              \
# ...

# %%
df_comp = df_comp.iloc[1:]
del df_comp['^N225']
del df_comp['^GSPC']
del df_comp['^GDAXI']
del df_comp['^FTSE']

# %%
df_comp.head()
# Out:
#                    spx          dax         ftse        nikkei
#
# Date
# 1994-01-10  475.269989  2225.000000  3440.600098  18443.439453
# 1994-01-11  474.130005  2228.100098  3413.800049  18485.250000
# 1994-01-12  474.170013  2182.060059  3372.000000  18793.880859
# 1994-01-13  472.470001  2142.370117  3360.000000  18577.259766
# 1994-01-14  474.910004  2151.050049  3400.600098  18973.699219

# %%
df_comp=df_comp.asfreq('D')

# %%
df_comp.head()
# Out:
#                    spx          dax         ftse        nikkei
#
# Date
# 1994-01-10  475.269989  2225.000000  3440.600098  18443.439453
# 1994-01-11  474.130005  2228.100098  3413.800049  18485.250000
# 1994-01-12  474.170013  2182.060059  3372.000000  18793.880859
# 1994-01-13  472.470001  2142.370117  3360.000000  18577.259766
# 1994-01-14  474.910004  2151.050049  3400.600098  18973.699219

# %%
df_comp = df_comp.iloc[1:]
del df_comp['^N225']
del df_comp['^GSPC']
del df_comp['^GDAXI']
del df_comp['^FTSE']
df_comp=df_comp.asfreq('b')
df_comp=df_comp.fillna(method='ffill')

# %%
df_comp
# Out:
#                     spx           dax         ftse        nikkei
#
# Date
# 1994-01-10   475.269989   2225.000000  3440.600098  18443.439453
# 1994-01-11   474.130005   2228.100098  3413.800049  18485.250000
# 1994-01-12   474.170013   2182.060059  3372.000000  18793.880859
# 1994-01-13   472.470001   2142.370117  3360.000000  18577.259766
# 1994-01-14   474.910004   2151.050049  3400.600098  18973.699219
# ...                 ...           ...          ...           ...
# 2020-05-11  2930.189941  10824.990234  5939.700195  20390.660156
# 2020-05-12  2870.120117  10819.500000  5994.799805  20366.480469
# 2020-05-13  2820.000000  10542.660156  5904.100098  20267.050781
# 2020-05-14  2852.500000  10337.019531  5741.500000  19914.779297
# 2020-05-15  2863.699951  10465.169922  5799.799805  20037.470703
#
# [6875 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
#plt.figure(figsize=(20,6))
df_comp.plot(figsize=(10,6),color=['red','blue','orange','black'])
plt.show()

# %%
import matplotlib.pyplot as plt
#plt.figure(figsize=(20,6))
df_comp['spx'].plot(figsize=(10,6),color=['red'])
plt.show()
