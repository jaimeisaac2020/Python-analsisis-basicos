# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimeisaac2020/Python-analsisis-basicos/blob/mi-github/5_Performing_univariate_analysis_using_a_Bar_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Import relevant libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load dataset

# %%
penguins_data = pd.read_csv("penguins_size.csv")

# %% [markdown]
# #### Subset for relevant columns

# %%
penguins_data = penguins_data[['species','culmen_length_mm']]

# %% [markdown]
# #### Inspect first 5 rows and data types of the dataset

# %%
penguins_data.head()
# Out:
#   species  culmen_length_mm
# 0  Adelie              39.1
# 1  Adelie              39.5
# 2  Adelie              40.3
# 3  Adelie               NaN
# 4  Adelie              36.7

# %%
penguins_data.shape
# Out:
# (344, 2)

# %%
penguins_data.dtypes
# Out:
# species              object
# culmen_length_mm    float64
# dtype: object

# %% [markdown]
# #### Create a bar plot using countplot method in Seaborn

# %%
x_values = penguins_data['species'].unique()
y_values = penguins_data['species'].value_counts().tolist()
plt.bar(x_values, y_values)
plt.show()
plt.close('all')

# %%
plt.figure()    #Figura. Puede incluirse el tamaño con figsize
plt.bar(x_values, y_values)          #El gráfico
plt.title('Pedidos de postres')      #El título
ax = plt.subplot()                   #Axis
ax.set_xticks(x_values)             #Eje x
ax.set_xticklabels(x_values)        #Etiquetas del eje x
ax.set_xlabel('Petición de postre')  #Nombre del eje x
ax.set_ylabel('Volumen de peticiones')  #Nombre del eje y
# Out:
# Text(0, 0.5, 'Volumen de peticiones')

# %%
plt.figure()                                #Figura
x_values1 = penguins_data.species.unique()
y_values1 = penguins_data.species.value_counts().tolist()
ax = plt.subplot(1, 3, 1)                   #Axis
plt.bar(x_values1, y_values1)               #El gráfico
plt.bar(x_values1, y_values1)
plt.bar(x_values1, y_values1)
plt.title('Pedidos de comida')              #El título
ax.set_xticks(x_values1)                    #Eje x
ax.set_xticklabels(x_values1, rotation=60)  #Etiquetas del eje x
ax.set_xlabel('Tipos de comida')            #Nombre del eje x
ax.set_ylabel('Volumen de peticiones')      #Nombre del eje y
# Out:
# Text(0, 0.5, 'Volumen de peticiones')

# %%
sns.countplot(data = penguins_data, x= penguins_data['species'])
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# #### Provide additional chart details

# %%
plt.figure(figsize= (12,6))

ax = sns.countplot(data = penguins_data, x= penguins_data['species'])
ax.set_xlabel('Penguin Species',fontsize = 15)
ax.set_ylabel('Count of records',fontsize = 15)
ax.set_title('Univariate analysis of Penguin Species', fontsize= 20)
# Out:
# Text(0.5, 1.0, 'Univariate analysis of Penguin Species')
