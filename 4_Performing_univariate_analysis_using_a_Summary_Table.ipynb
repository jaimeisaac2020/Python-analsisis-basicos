# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimeisaac2020/Python-analsisis-basicos/blob/mi-github/4_Performing_univariate_analysis_using_a_Summary_Table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Import relevant libraries

# %%
import pandas as pd

# %% [markdown]
# #### Load dataset

# %%
houseprices_data = pd.read_csv("HousingPricesData.csv")

# %% [markdown]
# #### Subset for relevant columns

# %%
houseprices_data = houseprices_data[['Zip','Price']]

# %% [markdown]
# #### Inspect first 5 rows and data types of the dataset

# %%
houseprices_data.head()
# Out:
#        Zip     Price
# 0  1091 CR  685000.0
# 1  1059 EL  475000.0
# 2  1097 SM  850000.0
# 3  1060 TH  580000.0
# 4  1036 KN  720000.0

# %%
houseprices_data.shape
# Out:
# (924, 2)

# %%
houseprices_data.dtypes
# Out:
# Zip       object
# Price    float64
# dtype: object

# %% [markdown]
# #### Create a Summary Table using the describe method in Pandas

# %%
houseprices_data.describe()
# Out:
#               Price
# count  9.200000e+02
# mean   6.220654e+05
# std    5.389942e+05
# min    1.750000e+05
# 25%    3.500000e+05
# 50%    4.670000e+05
# 75%    7.000000e+05
# max    5.950000e+06
